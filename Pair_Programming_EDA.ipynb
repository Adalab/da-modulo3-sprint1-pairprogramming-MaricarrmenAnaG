# %% [markdown]
# 1. Ejercicios de exploración del conjunto de datos

# %%
import pandas as pd
import numpy as np

# %%
df_world= pd.read_csv ("world-data-2023_part1.csv", index_col=0)
df_world.head (5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %%
df_world.tail(5)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %%
df_world.sample (5)
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 121        Nepal              203           NP                28.70%
# 163  South Sudan               18           SS                   NaN
# 61         Gabon                9           GA                20.00%
# 142      Romania               84           RO                58.80%
# 90        Kuwait              240           KW                 8.40%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 121        147,181           112,000       19.89         977.0
# 163        644,329           185,000       35.01         211.0
# 61         267,667             7,000       31.61         241.0
# 142        238,391           126,000        9.60          40.0
# 90          17,818            25,000       13.94         965.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 121          Kathmandu         9,105    188.73          5.60%           NPR
# 163               Juba         1,727  4,583.71        187.90%           SSP
# 61          Libreville         5,321    122.19          2.10%           XAF
# 142          Bucharest        69,259    123.78          3.80%           RON
# 90         Kuwait City        98,734     126.6          1.10%           KWD
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 121            1.92            25.40%         $0.91
# 163            4.70               NaN         $0.28
# 61             3.97            90.00%         $0.92
# 142            1.71            30.10%         $1.16
# 90             2.08             0.40%         $0.35

# %%
print(f"El número de filas que tenemos es {df_world.shape[0]}, y el número de columnas es {df_world.shape[1]}")
# Out:
# El número de filas que tenemos es 195, y el número de columnas es 16

# %%
df_world.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %%
df_world ["Abbreviation"].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %%
df_world ["Abbreviation"].value_counts()
# Out:
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: Abbreviation, Length: 188, dtype: int64

# %%
df_world.isnull()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0      False             False         False                  False
# 1      False             False         False                  False
# 2      False             False         False                  False
# 3      False             False         False                  False
# 4      False             False         False                  False
# ..       ...               ...           ...                    ...
# 190    False             False         False                  False
# 191    False             False         False                  False
# 192    False             False         False                  False
# 193    False             False         False                  False
# 194    False             False         False                  False
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0             False              False       False         False
# 1             False              False       False         False
# 2             False              False       False         False
# 3             False               True       False         False
# 4             False              False       False         False
# ..              ...                ...         ...           ...
# 190           False              False       False         False
# 191           False              False       False         False
# 192           False              False       False         False
# 193           False              False       False         False
# 194           False              False       False         False
#
#      Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  Currency-Code  \
# 0                 False          False  False           False          False
# 1                 False          False  False           False          False
# 2                 False          False  False           False          False
# 3                 False          False   True            True          False
# 4                 False          False  False           False          False
# ..                  ...            ...    ...             ...            ...
# 190               False          False  False           False          False
# 191               False          False  False           False          False
# 192               False          False  False           False          False
# 193               False          False  False           False          False
# 194               False          False  False           False           True
#
#      Fertility Rate  Forested Area (%)  Gasoline Price
# 0             False              False           False
# 1             False              False           False
# 2             False              False           False
# 3             False              False           False
# 4             False              False           False
# ..              ...                ...             ...
# 190           False              False           False
# 191           False              False           False
# 192           False              False           False
# 193           False              False           False
# 194           False              False           False
#
# [195 rows x 16 columns]

# %%
df_world.notnull()
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0       True              True          True                   True
# 1       True              True          True                   True
# 2       True              True          True                   True
# 3       True              True          True                   True
# 4       True              True          True                   True
# ..       ...               ...           ...                    ...
# 190     True              True          True                   True
# 191     True              True          True                   True
# 192     True              True          True                   True
# 193     True              True          True                   True
# 194     True              True          True                   True
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0              True               True        True          True
# 1              True               True        True          True
# 2              True               True        True          True
# 3              True              False        True          True
# 4              True               True        True          True
# ..              ...                ...         ...           ...
# 190            True               True        True          True
# 191            True               True        True          True
# 192            True               True        True          True
# 193            True               True        True          True
# 194            True               True        True          True
#
#      Capital/Major City  Co2-Emissions    CPI  CPI Change (%)  Currency-Code  \
# 0                  True           True   True            True           True
# 1                  True           True   True            True           True
# 2                  True           True   True            True           True
# 3                  True           True  False           False           True
# 4                  True           True   True            True           True
# ..                  ...            ...    ...             ...            ...
# 190                True           True   True            True           True
# 191                True           True   True            True           True
# 192                True           True   True            True           True
# 193                True           True   True            True           True
# 194                True           True   True            True          False
#
#      Fertility Rate  Forested Area (%)  Gasoline Price
# 0              True               True            True
# 1              True               True            True
# 2              True               True            True
# 3              True               True            True
# 4              True               True            True
# ..              ...                ...             ...
# 190            True               True            True
# 191            True               True            True
# 192            True               True            True
# 193            True               True            True
# 194            True               True            True
#
# [195 rows x 16 columns]

# %%
df_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %%
df_world.drop("Armed Forces size", axis=1, inplace=True)

# %%
df_world.describe(include='object')  ####INCOMPLETO####
# Out:
#             Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# count           195              195          188                   188
# unique          195              137          188                   168
# top     Afghanistan               25           AF                17.40%
# freq              1                7            1                     3
#
#        Land Area(Km2) Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# count             194                192           188     178            179
# unique            194                192           184     175             86
# top           652,230              Kabul           143  110.62          2.80%
# freq                1                  1             2       2              7
#
#        Currency-Code Forested Area (%) Gasoline Price
# count            180               188            175
# unique           133               161            101
# top              EUR            43.10%         $0.71
# freq              23                 3              6

# %% [markdown]
# 1. Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc

# %%
df_world.loc [2:4, :]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 2  Algeria               18           DZ                17.40%      2,381,741
# 3  Andorra              164           AD                40.00%            468
# 4   Angola               26           AO                47.50%      1,246,700
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 2       24.28         213.0            Algiers       150,006  151.36
# 3        7.20         376.0   Andorra la Vella           469     NaN
# 4       40.73         244.0             Luanda        34,693  261.73
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 2          2.00%           DZD            3.02             0.80%
# 3            NaN           EUR            1.27            34.00%
# 4         17.10%           AOA            5.52            46.30%
#
#   Gasoline Price
# 2         $0.28
# 3         $1.51
# 4         $0.97

# %% [markdown]
# 2. Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.

# %%
df_world.loc [df_world['Birth Rate']>30, :]

# %% [markdown]
# 3. Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.

# %%
df_world.loc[df_world['Fertility Rate']>3, ['Country', 'Capital/Major City']]

# %% [markdown]
# 4. Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.

# %%
df_world.loc[df_world['Abbreviation']=='AL', 'Gasoline Price']
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %% [markdown]
# 5. Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.

# %%
df_world.loc[df_world ['Capital/Major City'] == 'Tirana', : ]
# Out:
#    Country Density\n(P/Km2) Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 1  Albania              105           AL                43.10%         28,748
#
#    Birth Rate  Calling Code Capital/Major City Co2-Emissions     CPI  \
# 1       11.78         355.0             Tirana         4,536  119.05
#
#   CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 1          1.40%           ALL            1.62            28.10%
#
#   Gasoline Price
# 1         $1.36

# %% [markdown]
# 6. Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.

# %%
df_world.loc[df_world ['CPI'] == 128.85, :]  ### REVISAR
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price]
# Index: []

# %% [markdown]
# 7. Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.

# %%
df_world.loc[df_world ["Density\n(P/Km2)"]== 'AD']   ### REVISAR
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price]
# Index: []

# %% [markdown]
# 8. Selecciona las columnas "Country" y "Co2-Emissions".

# %%
df_world.columns[df_world ["Country", "Co2-Emissions"]]
